# %% [markdown]
# https://huggingface.github.io/candle/guide/installation.html
#
# https://github.com/huggingface/candle

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y

import os
os.environ["PATH"] += ":/root/.cargo/bin"

# !rustc --version
# !cargo --version
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: latest update on 2025-01-30, rust version 1.84.1 (e71f9a9a9 2025-01-27)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
#  26.7 MiB /  26.7 MiB (100 %)  21.4 MiB/s in  1s ETA:  0s
# info: downloading component 'rustc'
#  70.6 MiB /  70.6 MiB (100 %)  20.5 MiB/s in  3s ETA:  0s
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
#   8.8 MiB /   8.8 MiB (100 %)   7.9 MiB/s in  1s ETA:  0s
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  16.5 MiB /  16.5 MiB (100 %)   1.8 MiB/s in  7s ETA:  0s
# info: installing component 'rust-std'
#  26.7 MiB /  26.7 MiB (100 %)   6.3 MiB/s in  4s ETA:  0s
# info: installing component 'rustc'
# ...

# %%
# !cargo new myapp
# %cd myapp
# !cargo add --git https://github.com/huggingface/candle.git candle-core
# Out:
#     Creating binary (application) `myapp` package
# note: see more `Cargo.toml` keys and their definitions at https://doc.rust-lang.org/cargo/reference/manifest.html
# /content/myapp
#     Updating git repository `https://github.com/huggingface/candle.git`
#     Updating git submodule `https://github.com/NVIDIA/cutlass.git`
#       Adding candle-core (git) to dependencies
#              Features:
#              - accelerate
#              - cuda
#              - cudarc
#              - cudnn
#              - metal
#              - mkl
#     Updating git repository `https://github.com/huggingface/candle.git`
#     Updating crates.io index
#      Locking 118 packages to latest compatible versions

# %%
# !cargo build
# Out:
# ...
#   Downloaded bitflags v1.3.2
#   Downloaded bytemuck_derive v1.8.1
#   Downloaded gemm-f32 v0.17.1
#   Downloaded gemm v0.17.1
#   Downloaded gemm-c32 v0.17.1
#   Downloaded equivalent v1.0.1
#   Downloaded gemm-f64 v0.18.2
#   Downloaded gemm-c64 v0.18.2
#   Downloaded zerofrom v0.1.5
#   Downloaded gemm-c64 v0.17.1
#   Downloaded reborrow v0.5.5
#   Downloaded num_cpus v1.16.0
#   Downloaded gemm-c32 v0.18.2
#   Downloaded paste v1.0.15
#   Downloaded rand_chacha v0.3.1
#   Downloaded thiserror-impl v1.0.69
#   Downloaded dyn-stack v0.10.0
#   Downloaded synstructure v0.13.1
#   Downloaded zerofrom-derive v0.1.5
#   Downloaded stable_deref_trait v1.2.0
#   Downloaded itoa v1.0.14
#   Downloaded yoke-derive v0.7.5
#   Downloaded toml_datetime v0.6.8
#   Downloaded gemm-f16 v0.18.2
#   Downloaded gemm-f16 v0.17.1
#   Downloaded either v1.13.0
#   Downloaded dyn-stack v0.13.0
#   Downloaded num_enum_derive v0.7.3
#   Downloaded seq-macro v0.3.5
#   Downloaded rand_core v0.6.4
# ...

# %%
# !cargo add hf-hub
# Out:
#     Updating crates.io index
#       Adding hf-hub v0.4.1 to dependencies
#              Features:
#              + default-tls
#              + native-tls
#              + tokio
#              + ureq
#              - rustls-tls
#     Updating crates.io index
#      Locking 154 packages to latest compatible versions
#       Adding addr2line v0.24.2
#       Adding adler2 v2.0.0
#       Adding atomic-waker v1.1.2
#       Adding backtrace v0.3.74
#       Adding base64 v0.22.1
#       Adding bumpalo v3.17.0
#       Adding bytes v1.10.0
#       Adding cc v1.2.14
#       Adding console v0.15.10
#       Adding core-foundation v0.9.4
#       Adding core-foundation-sys v0.8.7
#       Adding dirs v5.0.1
#       Adding dirs-sys v0.4.1
#       Adding encode_unicode v1.0.0
#       Adding encoding_rs v0.8.35
#       Adding errno v0.3.10
#       Adding fastrand v2.3.0
#       Adding flate2 v1.0.35
#       Adding fnv v1.0.7
#       Adding foreign-types v0.3.2
# ...

# %%
# !cargo new ww
# %cd ww

# %%
# !cargo run

# %%
# !cargo run --example bert --release -- --prompt "Here is a test sentence"
# Out:
# error: no example target named `bert`.

# %%
# !git clone https://github.com/huggingface/candle.git
# Out:
# Cloning into 'candle'...
# remote: Enumerating objects: 21168, done.
# remote: Counting objects: 100% (4605/4605), done.
# remote: Compressing objects: 100% (491/491), done.
# remote: Total 21168 (delta 4299), reused 4117 (delta 4114), pack-reused 16563 (from 2)
# Receiving objects: 100% (21168/21168), 11.82 MiB | 15.54 MiB/s, done.
# Resolving deltas: 100% (14531/14531), done.

# %%
# %cd /content/myapp/candle/candle-examples/examples
# !cargo run --example bert --release -- --prompt "Here is a test sentence"
# Out:
# /content/myapp/candle/candle-examples/examples
#     Updating crates.io index
#      Locking 620 packages to latest compatible versions
#       Adding anstyle-wincon v3.0.6 (available: v3.0.7)
#       Adding fancy-regex v0.13.0 (available: v0.14.0)
#       Adding gemm v0.17.1 (available: v0.18.2)
#       Adding getrandom v0.2.15 (available: v0.3.1)
#       Adding imageproc v0.24.0 (available: v0.25.0)
#       Adding metal v0.27.0 (available: v0.31.0)
#       Adding once_cell v1.19.0 (available: v1.20.3)
#       Adding parquet v51.0.0 (available: v54.1.0)
#       Adding pyo3 v0.22.6 (available: v0.23.4)
#       Adding pyo3-build-config v0.22.6 (available: v0.23.4)
#       Adding rand v0.8.5 (available: v0.9.0)
#       Adding rand_distr v0.4.3 (available: v0.5.0)
#       Adding regex v1.10.6 (available: v1.11.1)
#       Adding rubato v0.15.0 (available: v0.16.1)
#       Adding safetensors v0.4.5 (available: v0.5.2)
#       Adding thiserror v1.0.69 (available: v2.0.11)
# ...

# %%
# !cargo run --example mistral --release -- --prompt 'Write helloworld code in Rust' --sample-len 150
# Out:
#     Finished `release` profile [optimized] target(s) in 0.36s
#      Running `/content/myapp/candle/target/release/examples/mistral --prompt 'Write helloworld code in Rust' --sample-len 150`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# ..del-00002-of-00002.safetensors [00:00:36] [] 1.13 GiB/4.23 GiB 32.90 MiB/s (2m)                                                                               ^C

# %%
# !huggingface-cli login --token XXXXXXXXXXXXXXXX
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `read` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `read`

# %%
# !cargo run --example phi --release -- --prompt "def print_prime(n): "
# Out:
#    Compiling candle-examples v0.8.2 (/content/myapp/candle/candle-examples)
#     Finished `release` profile [optimized] target(s) in 23.34s
#      Running `/content/myapp/candle/target/release/examples/phi --prompt 'def print_prime(n): '`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# ..del-00001-of-00002.safetensors [00:02:24] [] 4.65 GiB/4.65 GiB 33.56 MiB/s (0s)                                                                               retrieved the files in 163.699317589s
# Running on CPU, to run on GPU, build this example with `--features cuda`
# config.json [00:00:00] [████████████████████████████████████] 735 B/735 B - (0s)loaded the model in 33.406612343s
# starting the inference loop
# def print_prime(n):
#     if n <= 1:
#         print("Not a prime number")
#     else:
#         for i in range(2, int(n**0.5)+1):
#             if (n % i) == 0:
#                 print("Not a prime number")
# ...

# %% [markdown]
# Running on CPU, to run on GPU, build this example with `--features cuda`

# %%
# !cargo run --example phi --release -- --prompt "Who is Napoleon Bonaparte?"
# Out:
#     Finished `release` profile [optimized] target(s) in 2.95s
#      Running `/content/myapp/candle/target/release/examples/phi --prompt 'Who is Napoleon Bonaparte?'`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# retrieved the files in 150.8378ms
# Running on CPU, to run on GPU, build this example with `--features cuda`
# loaded the model in 50.575414932s
# starting the inference loop
# Who is Napoleon Bonaparte?
# Answer: Napoleon Bonaparte was a French military and political leader who rose to prominence during the French Revolution. He became Emperor of France in 1804 and played a significant role in European history.
#
# Question 2: How did Napoleon rise to power?
# ...
